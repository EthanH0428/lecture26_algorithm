# %% [markdown]
# ### 1. 이진 트리 (Binary Tree)

# %%
class TreeNode:
def __init__(self, data, left, right):
self.data = data
self.left = left
self.right = right
def set_left(self, left):
    self.left = left
def set_right(self, right):
    set_right = right

# %%
my_tree = TreeNode('A', None, None)
my_tree.left = TreeNode('B', None, None)
my_tree.set_left(new_node)
my_tree.right = TreeNode('C', None, None)
my_tree.set_right(new_node)

cur_node = my_tree.left # 노드 B 객체(주소)
new_node = TreeNode('D', None, None)
cur_node.set_left(TreeNode(new_node))
new_node = TreeNode('E', None, None)
cur_node.set_right(TreeNode(new_node))

cur_node = my_tree.right
